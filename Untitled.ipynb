# %%
import os
import random
import shutil

# %%
# 원본 이미지와 라벨이 저장된 폴더 경로
images_dir = "/home/uit-lim/vspython/origin_files/images"
labels_dir = "/home/uit-lim/vspython/origin_files/labels"

print(images_dir)
print(labels_dir)
# Out:
# /home/uit-lim/vspython/origin_files/images
# 42

# %%
# 분리된 train, valid, test 데이터셋을 저장할 폴더 경로
train_dir = "/home/uit-lim/vspython/change_files/train"
valid_dir = "/home/uit-lim/vspython/change_files/vaild"
test_dir = "/home/uit-lim/vspython/change_files/test"

print(train_dir)
# Out:
# /home/uit-lim/vspython/change_files/train

# %%
# train, valid, test 비율
train_ratio = 0.8
valid_ratio = 0.1
test_ratio = 0.1

# %%
# images 폴더 내의 모든 파일을 불러옴
images = os.listdir(images_dir)


# 파일을 무작위로 섞음
random.shuffle(images)

# %%
# train, valid, test 데이터셋으로 분리
train_images = images[:int(len(images) * train_ratio)]
valid_images = images[int(len(images) * train_ratio):int(len(images) * (train_ratio + valid_ratio))]
test_images = images[int(len(images) * (train_ratio + valid_ratio)):]

# %%
# train, valid, test 폴더 생성
os.makedirs(train_dir, exist_ok=True)
os.makedirs(valid_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %%
# train 데이터셋 이동
for image in train_images:
    shutil.copy(os.path.join(images_dir, image), os.path.join(train_dir, image))
    shutil.copy(os.path.join(labels_dir, image.replace(".png", ".txt")), os.path.join(train_dir, image.replace(".png", ".txt")))

# %%
# valid 데이터셋 이동
for image in valid_images:
    shutil.copy(os.path.join(images_dir, image), os.path.join(valid_dir, image))
    shutil.copy(os.path.join(labels_dir, image.replace(".png", ".txt")), os.path.join(valid_dir, image.replace(".png", ".txt")))

# %%
# test 데이터셋 이동
for image in test_images:
    shutil.copy(os.path.join(images_dir, image), os.path.join(test_dir, image))
    shutil.copy(os.path.join(labels_dir, image.replace(".png", ".txt")), os.path.join(test_dir, image.replace(".png", ".txt")))

# %%
import torch
print(torch.__version__)
# Out:
# 1.12.1+cu102

# %%
# !python '/home/uit-lim/yolov5/train.py' --img 416 --batch 8 --epochs 100 --data /home/uit-lim/vspython/coco128.yaml --weights '/home/uit-lim/yolov5/yolov5m.pt'
# Out:
# train: weights=/home/uit-lim/yolov5/yolov5m.pt, cfg=, data=/home/uit-lim/vspython/coco128.yaml, hyp=../yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=0, project=../yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.2-177-g2373d54 Python-3.9.0 torch-1.12.1+cu102 CUDA:0 (Quadro P2200, 5051MiB)
#
# ...

# %%
# !python '/home/uit-lim/yolov5/train.py' --img 416 --batch 16 --epochs 50 --data /home/uit-lim/vspython/coco128.yaml --weights '/home/uit-lim/yolov5/yolov5m.pt'

# %%
# !python '/home/uit-lim/yolov5/train.py' --img 512 --batch 8 --epochs 100 --data /home/uit-lim/vspython/coco128.yaml --weights '/home/uit-lim/yolov5/yolov5m.pt'
# Out:
# train: weights=/home/uit-lim/yolov5/yolov5m.pt, cfg=, data=/home/uit-lim/vspython/coco128.yaml, hyp=../yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=0, project=../yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.2-177-g2373d54 Python-3.9.0 torch-1.12.1+cu102 CUDA:0 (Quadro P2200, 5051MiB)
#
# ...

# %%
# !python '/home/uit-lim/yolov5/train.py' --img 512 --batch 16 --epochs 50 --data /home/uit-lim/vspython/coco128.yaml --weights '/home/uit-lim/yolov5/yolov5m.pt'
